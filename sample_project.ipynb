# %% [markdown]
# <a href="https://colab.research.google.com/github/Maheen-Sabir/colab/blob/main/sample_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p forest_neuro_symbolic_ai/{data/images,data/metadata,data/videos,models,outputs/images,outputs/logs}
# !mkdir -p forest_neuro_symbolic_ai/src/{detection,context,rules,neuro_symbolic,utils}

# %%
pip install ultralytics opencv-python pillow numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.8 MB/s eta 0:00:00
# ...

# %%
# !wget https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt \
-O forest_neuro_symbolic_ai/models/yolov8n.pt
# Out:
# --2026-01-16 10:48:30--  https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python forest_neuro_symbolic_ai/src/main.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# image 1/1 /content/forest_neuro_symbolic_ai/data/images/lion.jpg: 512x640 1 sheep, 76.9ms
# Speed: 15.8ms preprocess, 76.9ms inference, 48.5ms postprocess per image at shape (1, 3, 512, 640)
# Decision: ACCEPT
# Final Score: 0.6834735870361328
# Reasons: ['Small object size']

# %%
# !python forest_neuro_symbolic_ai/src/main.py
# Out:
# python3: can't open file '/content/forest_neuro_symbolic_ai/src/main.py': [Errno 2] No such file or directory

# %%
# !python forest_neuro_symbolic_ai/src/main.py
# Out:
# python3: can't open file '/content/forest_neuro_symbolic_ai/src/main.py': [Errno 2] No such file or directory
